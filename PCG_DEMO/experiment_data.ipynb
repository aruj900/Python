# %%
import camelot
tables = camelot.read_pdf('docs/Keytruda PI.pdf',pages="8", flag_size=True,shift_text=['/n'])

# %%
tables[0].df
# Out:
#                                                     0  \
# 0                                          Indication
# 1                                         Monotherapy
# 2   Adult patients with unresectable or \nmetastat...
# 3   Adjuvant treatment of adult patients \nwith me...
# 4   Adult patients with NSCLC, SCLC, \nHNSCC, cHL,...
# 5   Adult patients with high-risk BCG-\nunresponsi...
# 6   Pediatric patients with cHL, PMBCL, \nMSI-H Ca...
# 7                        Combination Therapy<s>† </s>
# 8   Adult patients with NSCLC, HNSCC, or \nEsophag...
# 9                             Adult patients with RCC
# 10        Adult patients with Endometrial \nCarcinoma
# 11  Adult patients with locally recurrent \nunrese...
#
#                                                     1  \
# 0                  Recommended Dosage of\n \nKEYTRUDA
# 1
# 2   200 mg every 3 weeks* \nor \n400 mg every 6 we...
# 3   200 mg every 3 weeks* \nor \n400 mg every 6 we...
# ...

# %%
import camelot
tables = camelot.read_pdf('docs/Keytruda PI.pdf',pages="9", copy_text=['v'], flag_size=True,shift_text=['/n'],process_background=False,line_scale=5)

# %%
tables[0].df
# Out:
#                                                     0  \
# 0                                    Adverse Reaction
# 1   Immune-Mediated Adverse Reactions [see Warning...
# 2
# 3                                         Pneumonitis
# 4
# 5                                             Colitis
# 6   Hepatitis with no tumor involvement \nof the l...
# 7   For liver enzyme elevations in \npatients trea...
# 8   Hepatitis with tumor involvement of \nthe live...
# 9   Hepatitis with tumor involvement of \nthe live...
# 10                                   Endocrinopathies
# 11
# 12                   Nephritis with Renal Dysfunction
# 13                Exfoliative Dermatologic Conditions
# 14                Exfoliative Dermatologic Conditions
# 15                                        Myocarditis
# 16
# 17                            Neurological Toxicities
# 18  Hematologic toxicity in patients with \ncHL or...
#
#                                                     1  \
# ...
